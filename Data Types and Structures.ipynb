# %%
#THEORETICAL QUESTIONS

# 1. What are data structures, and why are they important?
# Data structures are methods of organizing and managing data efficiently.
# They help optimize performance for operations like storage, access, and modification.

# 2. Explain the difference between mutable and immutable data types with examples.
# Mutable data types can be changed after creation, while immutable data types cannot.

# Example:
# Mutable Example:
mutable_list = [1, 2, 3]
mutable_list[0] = 4  # Modifies the list

# Immutable Example:
immutable_tuple = (1, 2, 3)
# immutable_tuple[0] = 4  # Uncommenting this will raise an error

# 3. What are the main differences between lists and tuples in Python?
# Lists are mutable, allowing modifications, while tuples are immutable, ensuring data integrity.
# Tuples are also faster than lists for iteration.

# 4. Describe how dictionaries store data.
# Dictionaries use a hash table to store data in key-value pairs, enabling fast data retrieval.

# 5. Why might you use a set instead of a list in Python?
# Sets are useful when duplicate values are not allowed and when fast membership checks are needed.

# 6. What is a string in Python, and how is it different from a list?
# Strings are sequences of characters and are immutable. Lists, on the other hand, are mutable
# and can store elements of various data types.

# 7. How do tuples ensure data integrity in Python?
# Tuples are immutable, meaning their values cannot be changed after creation, preserving integrity.

# 8. What is a hash table, and how does it relate to dictionaries in Python?
# A hash table maps keys to values using a hash function. Dictionaries in Python are implemented
# as hash tables, ensuring fast key-based lookups.

# 9. Can lists contain different data types in Python?
# Yes, lists can contain elements of various data types.

# 10. Explain why strings are immutable in Python.
# Strings are immutable to enhance security, memory efficiency, and compatibility with hash-based operations.

# 11. What advantages do dictionaries offer over lists for certain tasks?
# Dictionaries allow fast lookups using keys and store data in a key-value format, which is intuitive for many applications.

# 12. Describe a scenario where using a tuple would be preferable over a list.
# Tuples are preferred when working with fixed data, such as geographical coordinates, where values should not be altered.

# 13. How do sets handle duplicate values in Python?
# Sets automatically discard duplicate values, ensuring uniqueness of elements.

# 14. How does the “in” keyword work differently for lists and dictionaries?
# For lists, "in" checks for the presence of an element. For dictionaries, it checks for the presence of a key.

# 15. Can you modify the elements of a tuple? Explain why or why not.
# No, tuples are immutable, so their elements cannot be modified.

# 16. What is a nested dictionary, and give an example of its use case.
# A nested dictionary is a dictionary within another dictionary, useful for hierarchical data.

# Example:
nested_dict = {
    "Alice": {"age": 25, "grade": "A"},
    "Bob": {"age": 23, "grade": "B"}
}
print(nested_dict["Alice"]["grade"])  # Output: A

# 17. Describe the time complexity of accessing elements in a dictionary.
# The average time complexity of accessing elements in a dictionary is O(1).

# 18. In what situations are lists preferred over dictionaries?
# Lists are preferred when order is important or when key-value relationships are not required.

# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
# Dictionaries store elements based on hash values, not insertion order, but data retrieval is efficient via keys.

# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
# Lists use indices for retrieval, while dictionaries use keys, making dictionaries faster for specific lookups.

# PRACTICAL QUESTIONS

# 1. Create a string with your name and print it
my_name = "Anoop Singh"
print(my_name)

# 2. Find the length of the string "Hello World"
hello_world = "Hello World"
print(len(hello_world))

# 3. Slice the first 3 characters from the string "Python Programming"
python_string = "Python Programming"
print(python_string[:3])

# 4. Convert the string "hello" to uppercase
hello = "hello"
print(hello.upper())

# 5. Replace the word "apple" with "orange" in the string "I like apple"
fruit_string = "I like apple"
print(fruit_string.replace("apple", "orange"))

# 6. Create a list with numbers 1 to 5 and print it
my_list = [1, 2, 3, 4, 5]
print(my_list)

# 7. Append the number 10 to the list [1, 2, 3, 4]
list_with_10 = [1, 2, 3, 4]
list_with_10.append(10)
print(list_with_10)

# 8. Remove the number 3 from the list [1, 2, 3, 4, 5]
removal_list = [1, 2, 3, 4, 5]
removal_list.remove(3)
print(removal_list)

# 9. Access the second element in the list ['a', 'b', 'c', 'd']
letters_list = ['a', 'b', 'c', 'd']
print(letters_list[1])

# 10. Reverse the list [10, 20, 30, 40, 50]
reversed_list = [10, 20, 30, 40, 50]
reversed_list.reverse()
print(reversed_list)

# 11. Create a tuple with the elements 10, 20, 30 and print it
my_tuple = (10, 20, 30)
print(my_tuple)

# 12. Access the first element of the tuple ('apple', 'banana', 'cherry')
fruit_tuple = ('apple', 'banana', 'cherry')
print(fruit_tuple[0])

# 13. Count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)
count_tuple = (1, 2, 3, 2, 4, 2)
print(count_tuple.count(2))

# 14. Find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
animal_tuple = ('dog', 'cat', 'rabbit')
print(animal_tuple.index('cat'))

# 15. Check if the element "banana" is in the tuple ('apple', 'orange', 'banana')
check_tuple = ('apple', 'orange', 'banana')
print('banana' in check_tuple)

# 16. Create a set with the elements 1, 2, 3, 4, 5 and print it
my_set = {1, 2, 3, 4, 5}
print(my_set)

# 17. Add the element 6 to the set {1, 2, 3, 4}
add_set = {1, 2, 3, 4}
add_set.add(6)
print(add_set)

# 18. Create a tuple with the elements 10, 20, 30 and print it
another_tuple = (10, 20, 30)
print(another_tuple)

# 19. Access the first element of the tuple ('apple', 'banana', 'cherry')
another_fruit_tuple = ('apple', 'banana', 'cherry')
print(another_fruit_tuple[0])

# 20. Count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)
another_count_tuple = (1, 2, 3, 2, 4, 2)
print(another_count_tuple.count(2))

# 21. Find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
another_animal_tuple = ('dog', 'cat', 'rabbit')
print(another_animal_tuple.index('cat'))

# 22. Check if the element "banana" is in the tuple ('apple', 'orange', 'banana')
another_check_tuple = ('apple', 'orange', 'banana')
print('banana' in another_check_tuple)

# 23. Create a set with the elements 1, 2, 3, 4, 5 and print it
another_set = {1, 2, 3, 4, 5}
print(another_set)

# 24. Add the element 6 to the set {1, 2, 3, 4}
another_add_set = {1, 2, 3, 4}
another_add_set.add(6)
print(another_add_set)
